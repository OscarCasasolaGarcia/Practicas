# %% [markdown]
# # Tarea 2: Análisis exploratorio de datos
#
# Nombre: Casasola García Oscar
#
# No. Cuenta: 316123747
#
# Email: oscar.casasola.g7@gmail.com

# %% [markdown]
# ## Contexto
# La Copa Mundial de la FIFA es el torneo de fútbol más prestigioso del mundo. El campeonato se ha celebrado cada cuatro años desde el inicio del torneo en 1930.
#
# El formato actual implica una fase de clasificación, que tiene lugar durante los tres años anteriores, para determinar qué equipos califican para el torneo. En el torneo, 32 equipos, incluido el país anfitrión, compiten por el título en diferentes estadios del país anfitrión.
#
# El actual campeón es Francia, que venció a Croacia en el torneo de 2018 en Rusia. Qatar albergará el torneo de 2022, cuyo primer partido se jugará en noviembre.
#
# Este conjunto de datos proporciona una descripción completa de todos los partidos de fútbol internacionales jugados desde los años 90. Además de eso, la fortaleza de cada equipo se proporciona mediante la incorporación de clasificaciones reales de FIFA, así como las fortalezas de los jugadores basadas en el videojuego EA Sport FIFA.
#
# NOTA: el conjunto de datos se actualizó el 28-08-2022
#
# ## Objetivo:
# Identificar una fuente de datos (datos abiertos) para su importación en Google Colab o Jupyter a través de alguna plataforma Git (Github, Gitlab o algún otro) para realizar el proceso EDA.
#
#
# ## Fuente de datos
# Este conjunto de datos proporciona una descripción completa de todos los partidos de fútbol internacionales jugados desde los años 90. Además de eso, la fortaleza de cada equipo se proporciona mediante la incorporación de clasificaciones reales de FIFA, así como las fortalezas de los jugadores basadas en el videojuego EA Sport FIFA.
#
# 1) date: fecha del partido
# 2) home_team: nombre del equipo local
# 3) away_team: nombre del equipo visitante
# 4) home_team_continent: continente del equipo local
# 5) away_team_continent: continente del equipo visitante
# 6) home_team_fifa_rank: ranking FIFA del equipo local en el momento del partido
# 7) away_team_fifa_rank: ranking FIFA del equipo visitante en el momento del partido
# 8) home_team_total_fifa_points: puntos totales FIFA del equipo local en el momento del partido
# 9) away_team_total_fifa_points: puntos totales FIFA del equipo visitante en el momento del partido
# 10) home_team_score: goles del equipo local a tiempo completo, incluida la prórroga, sin incluir las tandas de penaltis
# 11) away_team_score: goles del equipo visitante a tiempo completo, incluida la prórroga, sin incluir las tandas de penaltis
# 12) tournament: nombre del torneo
# 13) city: nombre de la ciudad/pueblo/unidad administrativa donde se jugó el partido
# 14) country: nombre del país donde se jugó el partido
# 15) neutral_location: si el partido se jugó en un lugar neutral (TRUE o FALSE)
# 16) shoot_out: si el partido se decidió en las tandas de penaltis (TRUE o FALSE)
# 17) home_team_result: resultado del partido para el equipo local, incluida la tanda de penaltis (win, lose, draw)
# 18) home_team_goalkeeper_score: puntuación del juego FIFA del portero mejor clasificado del equipo local
# 19) away_team_goalkeeper_score: puntuación del juego FIFA del portero mejor clasificado del equipo visitante
# 20) home_team_mean_defense_score: promedio de puntaje de juego de FIFA de los 4 jugadores defensivos mejor clasificados del equipo local
# 21) home_team_mean_offense_score: promedio de puntaje de juego de FIFA de los 4 jugadores ofensivos mejor clasificados del equipo local
# 22) home_team_mean_midfield_score: promedio de puntaje de juego de FIFA de los 4 jugadores del medio campo mejor clasificados del equipo local
# 23) away_team_mean_defense_score: promedio de puntaje de juego de FIFA de los 4 jugadores defensivos mejor clasificados del equipo visitante
# 24) away_team_mean_offense_score: promedio de puntaje de juego de FIFA de los 4 jugadores ofensivos mejor clasificados del equipo visitante
# 25) away_team_mean_midfield_score: promedio de puntaje de juego de FIFA de los 4 jugadores del medio campo mejor clasificados del equipo visitante

# %% [markdown]
# ### Importar las bibliotecas y los datos

# %%
import pandas as pd               # Para la manipulación y análisis de datos
import numpy as np                # Para crear vectores y matrices n dimensionales
import matplotlib.pyplot as plt   # Para la generación de gráficas a partir de los datos
import seaborn as sns             # Para la visualización de datos basado en matplotlib

# %matplotlib inline          
# Para generar y almacenar los gráficos dentro del cuaderno

# %%
# ! Cargamos el conjunto de datos
# * En Google Colab:
# from google.colab import files
# files.upload()

# * En Jupyter Notebook (de manera local):
# DatosMelbourne = pd.read_csv("melb_data.csv")

# * Desde un repositorio de GitHub:
URL = "https://raw.githubusercontent.com/OscarCasasolaGarcia/Practicas/master/1EDA/international_matches.csv"
DatosMatches = pd.read_csv(URL)

# Mostramos la información del conjunto de datos
DatosMatches
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
DatosMatches.tail()
# Out:
#              date       home_team away_team home_team_continent  \
# 23916  2022-06-14         Moldova   Andorra              Europe
# 23917  2022-06-14   Liechtenstein    Latvia              Europe
# 23918  2022-06-14           Chile     Ghana       South America
# 23919  2022-06-14           Japan   Tunisia                Asia
# 23920  2022-06-14  Korea Republic     Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 23916              Europe                  180                  153
# 23917              Europe                  192                  135
# 23918              Africa                   28                   60
# 23919              Africa                   23                   35
# 23920              Africa                   29                   32
#
#        home_team_total_fifa_points  away_team_total_fifa_points  \
# 23916                          932                         1040
# ...

# %% [markdown]
# # Paso 1: Descripción de la estructura de los datos
#
# ## 1.1) Forma (dimensiones) del DataFrame
#
# El atributo **shape** de Pandas proporciona una estructura general de los datos. Devuelve la cantidad de filas y columnas que tiene el conjunto de datos.

# %%
DatosMatches.shape
# Out:
# (23921, 25)

# %% [markdown]
# ## 1.2) Tipos de datos (variables)
#
# El atributo **dtypes** muestra los tipos de datos de las columnas (variables y tipos).

# %%
DatosMatches.dtypes
# Out:
# date                              object
# home_team                         object
# away_team                         object
# home_team_continent               object
# away_team_continent               object
# home_team_fifa_rank                int64
# away_team_fifa_rank                int64
# home_team_total_fifa_points        int64
# away_team_total_fifa_points        int64
# home_team_score                    int64
# away_team_score                    int64
# tournament                        object
# city                              object
# country                           object
# neutral_location                    bool
# shoot_out                         object
# home_team_result                  object
# home_team_goalkeeper_score       float64
# away_team_goalkeeper_score       float64
# home_team_mean_defense_score     float64
# home_team_mean_offense_score     float64
# home_team_mean_midfield_score    float64
# away_team_mean_defense_score     float64
# ...

# %% [markdown]
# Se observa que el conjunto de datos tiene una combinación de variables categóricas (objeto) y numéricas (flotante e int).

# %% [markdown]
# # Paso 2: Identificación de datos faltantes
#
# Una función útil de pandas es **.isnull().sum()** que regresa la suma de todos los valores nulos en cada variable.

# %%
DatosMatches.isnull().sum()
# Out:
# date                                 0
# home_team                            0
# away_team                            0
# home_team_continent                  0
# away_team_continent                  0
# home_team_fifa_rank                  0
# away_team_fifa_rank                  0
# home_team_total_fifa_points          0
# away_team_total_fifa_points          0
# home_team_score                      0
# away_team_score                      0
# tournament                           0
# city                                 0
# country                              0
# neutral_location                     0
# shoot_out                            0
# home_team_result                     0
# home_team_goalkeeper_score       15542
# away_team_goalkeeper_score       15826
# home_team_mean_defense_score     16134
# home_team_mean_offense_score     15411
# home_team_mean_midfield_score    15759
# away_team_mean_defense_score     16357
# away_team_mean_offense_score     15609
# ...

# %% [markdown]
# - Se podrían eliminar los datos faltantes si es que es una variable significativa.
# - Otra solución sería completar los datos faltantes, los cuales se pueden completar con distintas técnicas.

# %% [markdown]
# También se puede usar **info()** para obtener el tipo de datos y la suma de valores nulos.

# %%
DatosMatches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23921 entries, 0 to 23920
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           23921 non-null  object
#  1   home_team                      23921 non-null  object
#  2   away_team                      23921 non-null  object
#  3   home_team_continent            23921 non-null  object
#  4   away_team_continent            23921 non-null  object
#  5   home_team_fifa_rank            23921 non-null  int64
#  6   away_team_fifa_rank            23921 non-null  int64
#  7   home_team_total_fifa_points    23921 non-null  int64
#  8   away_team_total_fifa_points    23921 non-null  int64
#  9   home_team_score                23921 non-null  int64
#  10  away_team_score                23921 non-null  int64
#  11  tournament                     23921 non-null  object
# ...

# %% [markdown]
# # Paso 3: Detección de valores atípicos
#
# Se pueden utilizar gráficos para tener una idea general de las distribuciones de los datos, y se sacan estadísticas para resumir los datos. Estas dos estrategias son recomendables y se complementan.
#
# La distribución se refiere a cómo se distribuyen los valores en una variable o con qué frecuencia ocurren.
#
# Para las variables numéricas, se observa cuántas veces aparecen grupos de números en una columna.
#
# Mientras que para las variables categóricas, son las clases de cada columna y su frecuencia.

# %% [markdown]
# ## 3.1) Distribución de variables numéricas
#
# * Se utilizan histogramas que agrupan los números en rangos.
# * La altura de una barra muestra cuántos números caen en ese rango.
# * Se emplea **hist()** para trazar el histograma de las variables numéricas. También se pueden usar los parámetros: **figsize** y **xrot** para aumentar el tamaño de la cuadrícula y rotar el eje x 45 grados.

# %%
DatosMatches.hist(figsize=(14,14), xrot=45)
plt.show()

# %% [markdown]
# ### Qué buscar:
#
# * Posibles valores atípicos, que pueden ser errores de medición.
# * Límites que no tienen sentido, como valores porcentuales > 100.
#
# En el histograma, se observa que:
# - **home_team_total_fifa_points** y **away_team_total_fifa_points** tienen valores sesgados a la izquierda.
# - Las variables **home_team_score** y **away_team_score** también están sesgada hacia la izquierda.
#
# Cómo solucionarlo:
# - Eliminar los valores atípicos, pero antes se debe verificar que los datos son verdaderos.
# - Modificar los datos atípicos, si es que hubo un error.
#
# En resumen, se debe preguntar al proveedor de los datos y validar si es que los datos proporcionados son verdaderos.
#
# En este caso, estos valores están sesgados a la izquierda debido a:
# - **home_team_total_fifa_points** y **away_team_total_fifa_points**: debido a que la puntuación de FIFA de las selecciones nacionales es más frecuente en los valores más bajos.
# - **home_team_score** y **away_team_score**: debido a que muy rara vez hay más de 6 goles por partido.

# %% [markdown]
# ## 3.2) Resumen estadístico de variables numéricas
#
# Se sacan estadísticas usando **describe()** que muestra un resumen estadístico de las variables numéricas.

# %%
DatosMatches.describe()
# Out:
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# count         23921.000000         23921.000000                 23921.000000
# mean             77.854688            80.797375                   323.401488
# std              52.355225            53.232902                   500.825725
# min               1.000000             1.000000                     0.000000
# 25%              33.000000            36.000000                     0.000000
# 50%              71.000000            73.000000                     0.000000
# 75%             115.000000           119.000000                   547.000000
# max             211.000000           211.000000                  2164.000000
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# count                 23921.000000     23921.000000     23921.000000
# mean                    315.453576         1.609214         1.068266
# ...

# %% [markdown]
# * Se incluye un recuento, media, desviación, valor mínimo, percentil inferior (25%), 50%, percentil superior (75%) y valor máximo.
# * Por defecto, el percentil 50 es lo mismo que la mediana.
# * Se observa que para cada variable, el recuento también ayuda a identificar variables con valores perdidos. Estos son: **home_team_total_fifa_points**, **away_team_total_fifa_points**, **home_team_score** y **away_team_score**.

# %% [markdown]
# ## 3.3) Diagramas para detectar posibles valores atípicos
#
# Para este tipo de gráficos se utiliza **Seaborn**, que permite generar diagramas de cajas para detectar valores atípicos.

# %%
VariablesValoresAtipicos = ['home_team_total_fifa_points','away_team_total_fifa_points','home_team_score','away_team_score']
for col in VariablesValoresAtipicos:
  sns.boxplot(col, data=DatosMatches)
  plt.show()
# Out:
# c:\Users\johnc\anaconda3\envs\IA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\johnc\anaconda3\envs\IA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\johnc\anaconda3\envs\IA\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %% [markdown]
# Se observa que **home_team_total_fifa_points** y **away_team_total_fifa_points** tienen valores atípicos.
# Al hacer un análisis de los datos, se observa que los valores atípicos son debido a que en esas fechas, se enfrentaron selecciones que tenían un puntaje FIFA muy elevado, tales como semifinales o finales del mundial. Estos partidos no son muy comunes, y se puede observar en el histograma presentado anteriormente.
#
# En el caso de **home_team_score** y **away_team_score**, se observa que hay valores atípicos, y habría que corroborar la naturaleza de estos datos, ya que según estos diagramas de caja, hubo partidos en los que se anotaron más de 10 goles. Los casos más extraños, es donde la selección local anotó más de 30 goles, y la selección visitante anotó más de 20 goles, lo cual es muy extraño.

# %% [markdown]
# ## 3.4) Distribución de variables categóricas
#
# - Se refiere a la observación de las clases de cada columna (variable) y su frecuencia.
# - Aquí, los gráficos ayudan para tener una idea general de las distribuciones, mientras que las estadísticas dan números reales.

# %%
DatosMatches.describe(include='object')
# Out:
#               date home_team away_team home_team_continent  \
# count        23921     23921     23921               23921
# unique        5550       211       211                   6
# top     2012-02-29    Mexico    Zambia              Europe
# freq            66       316       243                7593
#
#        away_team_continent tournament   city country shoot_out  \
# count                23921      23921  23921   23921     23921
# unique                   6         82   1576     217         2
# top                 Europe   Friendly   Doha     USA        No
# freq                  7359       8558    397    1003     23589
#
#        home_team_result
# count             23921
# unique                3
# top                 Win
# freq              11761

# %% [markdown]
# * Esta tabla es diferente al de los valores numéricos. Aquí, se obtiene el recuento de los valores de cada variable, el número de clases únicas, la clase más frecuente y con qué frecuencia ocurre esa clase en el conjunto de datos.
# * Se observa que algunas clases tienen demasiados valores únicos, como **date** y **city**.
# * A partir de estos hallazgos, se puede a manera de ejemplo graficar las variables con 10 o menos clases únicas.

# %% [markdown]
# **Plot**
#
# * Para este tipo de gráficos se utiliza Seaborn, que permite generar un histograma para variables categóricas. Cada barra en el gráfico de conteo representa una clase.
# * Se crea un bucle para el conteo y distribución de las clases.
# * La sentencia select_dtypes(include = ’object’) selecciona las columnas categóricas con sus valores y las muestra.
# * Se incluye también If para elegir solo las tres columnas con 10 o menos clases usando **nunique() < 10**.

# %%
for col in DatosMatches.select_dtypes(include='object'):
  if DatosMatches[col].nunique()<10:sns.countplot(y=col, data=DatosMatches)
  plt.show()

# %% [markdown]
# ## 3.5) Agrupación por variables categóricas

# %%
from sys import displayhook # Se importa displayhook

for col in DatosMatches.select_dtypes(include='object'):
  if DatosMatches[col].nunique() < 10:
    displayhook(DatosMatches.groupby(col).agg(['mean']))
# Out:
#                     home_team_fifa_rank away_team_fifa_rank  \
#                                    mean                mean
# home_team_continent
# Africa                        89.544095           91.131691
# Asia                         102.751792          105.772539
# Europe                        54.682471           56.156196
# North America                 85.345960           89.572511
# Oceania                      121.788679          125.226415
# South America                 40.388254           51.429581
#
#                     home_team_total_fifa_points away_team_total_fifa_points  \
#                                            mean                        mean
# home_team_continent
# Africa                               291.501105                  285.902294
# Asia                                 238.269144                  241.071860
# Europe                               407.757013                  395.692480
# ...

# %% [markdown]
# # Paso 4: Identificación de relaciones entre pares variables
#
# - Una matriz de correlaciones es útil para analizar la relación entre las variables numéricas.
# - Se emplea la función **corr()**
#
# Para este punto, se agregaron unas columnas para poder ver si existe una correlación entre el resultado del juego con el ranking FIFA de la selección y el ratio del ataque del equipo local vs la defensa del equipo visitante.

# %%
# Se crea una columna con el resultado del partido
DatosMatches['match_result'] = np.where(DatosMatches['home_team_result']=='Win', 2, 
                        np.where(DatosMatches['home_team_result']=='Draw', 1, 0))

#Fifa rank delta del equipo local y visitante (los valores más altos indican que el equipo local es más fuerte que el equipo visitante)
DatosMatches['fifa_rank_delta'] = DatosMatches['away_team_fifa_rank'] - DatosMatches['home_team_fifa_rank']

#Ataque equipo local vs defensa equipo visitante (los valores más altos indican que el ataque del equipo local es más fuerte que la defensa del equipo visitante)
DatosMatches['offense/defense_ratio'] = DatosMatches['home_team_mean_offense_score'] / DatosMatches['away_team_mean_defense_score']

# %%
# Se eliminan las columnas que no se van a utilizar en el análisis
corr_mean = DatosMatches.drop(['home_team_total_fifa_points', 'away_team_total_fifa_points', 'neutral_location'],axis=1).corr(method = 'pearson') 
corr_mean
# Out:
#                                home_team_fifa_rank  away_team_fifa_rank  \
# home_team_fifa_rank                       1.000000             0.496644
# away_team_fifa_rank                       0.496644             1.000000
# home_team_score                          -0.127667             0.298982
# away_team_score                           0.219087            -0.158206
# home_team_goalkeeper_score               -0.640102            -0.248486
# away_team_goalkeeper_score               -0.210219            -0.626912
# home_team_mean_defense_score             -0.712681            -0.241540
# home_team_mean_offense_score             -0.706093            -0.254718
# home_team_mean_midfield_score            -0.736180            -0.256242
# away_team_mean_defense_score             -0.197999            -0.698827
# away_team_mean_offense_score             -0.219993            -0.703529
# away_team_mean_midfield_score            -0.219073            -0.730467
# ...

# %%
plt.figure(figsize=(14,7))
MatrizInf = np.triu(corr_mean)
sns.heatmap(corr_mean, cmap='RdBu_r', annot=True, mask=MatrizInf)
plt.show()

# %% [markdown]
# * Una correlación es un valor entre -1 y 1 que equivale a qué tan cerca se mueven simultáneamente los valores de dos variables.
# * Una correlación positiva significa que a medida que una característica aumenta, la otra también aumenta.
# * Una correlación negativa significa que a medida que una característica disminuye, la otra también disminuye.
# * Las correlaciones cercanas a 0 indican una relación débil, mientras que las más cercanas a -1 o 1 significan una relación fuerte.

# %% [markdown]
# Se observa una fuerte correlación positiva entre:
# - El puntaje del portero de la selección local con la puntuación del resto de su equipo (defensa, mediocampo y delantera).
# - El puntaje del portero de la selección visitante con la puntuación del resto de su equipo (defensa, mediocampo y delantera).
# - El puntaje de la defensa de la selección local con la puntuación del resto del equipo (mediocampo y delantera).
# - El puntaje de la ofensiva de la selección local con la puntuación del mediocampo y el ratio de la ofensiva/defensiva.
# En resumen, el puntaje del equipo tiene una correlación fuerte en general, ya que la mayoría de las veces los equipos están equilibrados en todos los aspectos. Rara vez se ve a una selección como Alemania con un muy buen mediocampo pero con una pésima defensa.
# Se observan fuertes correlaciones negativas en el puntaje FIFA de las selecciones con el puntaje medio de sus porteros, defensas, medios y delanteros, esto debido a que entre menos puntaje tengan estos jugadores, menor será el puntaje FIFA del equipo.
# Con respecto al resultado del partido, se observa que entre más anote la selección global y menos anote la selección visitante, habrá más posibilidades de que la local gane el juego.
